# %%
# %load_ext autoreload
# %autoreload 2

# %%
_include_('curriculum_vqa')

from cvqa.curriculum import plotter, VQAInstanceDistribution2
from cvqa import trainers, datasets, viz

concept_dict = {
        'color': ['blue', 'brown', 'cyan', 'gray'],  # , 'green', 'purple', 'red', 'yellow'],
        'material': ['metal', 'rubber', 'plastic'],
        'shape': ['triangle', 'circle', 'square']
    }

# vqa_dist = VQAInstanceDistribution2(concept_dict=concept_dict, prompt_types_filter=['retrieve_attribute'], d_img=16)
# vqa_dist = VQAInstanceDistribution2(concept_dict=concept_dict, prompt_types_filter=['exists', 'retrieve_attribute'], d_img=16)
vqa_dist = VQAInstanceDistribution2(concept_dict=concept_dict, d_img=24)
# Out:
# Img Encoder: Loss=0.000: 100%|██████████| 10/10 [00:03<00:00,  3.22it/s]

# %%
# ds_temp = vqa_dist.sample_dataset(images=20, prompts_per_image=3)
# VQAInstanceDistribution2.to_debug_rep(ds_temp)

# %%
import random
import numpy as np
import torch

seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

ds_train, ds_dev = datasets.Curriculum.from_samples(
    vqa_dist.sample_dataset(images=300, prompts_per_image=5),
    vqa_dist.sample_dataset(images=100, prompts_per_image=5),
)

ds_train
# Out:
# Root: -
# Samples: 883 (N_prompt=9, N_target=1)
# Concepts: 0
# Classes: 0
# Prompt Vocab Tokens:42
# Answer Vocab Tokens:21

# %%
trainer = trainers.VQATrainer(log_dir=None, progressbar='epochs')

def train_model(model, lr=1e-4, epochs=10, batch_size=32):
    
    tracker = None
#     tracker = traintracks.TrainTracker(root='traintracks/eval')
#     tracker.save_module(sys.modules['cvqa.models2'])
#     tracker.log_conf(model.args)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.1)
    
    train_loss, train_acc, dev_acc = trainer.train(
        model, ds_train, ds_dev, 
        optimizer, 
        optim_sched=scheduler,
        traintracker=tracker, num_epochs=epochs, batch_size=batch_size
    )
    
    return {
        'train_loss': train_loss, 
        'train_acc': train_acc, 
        'dev_acc': dev_acc
    }

# %%
import numpy as np
import torch
from cvqa.model_dev import answer_model

seed = 1
np.random.seed(seed)
torch.manual_seed(seed)

args = answer_model.default_args()
args['d_a'] = 4
args['d_w'] = args['d_c'] = 24
args['d_o'] = 24
args['d_k'] = 8
    
model = answer_model.ParentModel(ds_train.vocab, ds_train.ans_vocab, args)

print(trainer.evaluate(model, torch.utils.data.DataLoader(ds_train, batch_size=32)))
# Out:
# 0.04190260475651189

# %%
train_metrics = train_model(model, lr=4e-3, epochs=20, batch_size=32)
# Out:
# [epoch=19, steps=635, train_acc=0.99, dev_acc=0.99] loss: 0.155: 100%|██████████| 20/20 [00:07<00:00,  2.69it/s]

# %%
print(trainer.evaluate(model, torch.utils.data.DataLoader(ds_dev, batch_size=32)))
viz.plot_training(**train_metrics)
# Out:
# 0.9829931972789115

# %%
y_true, y_pred = trainer.get_predictions(model, ds_dev)
viz.one_word_conf_mat(y_true, y_pred, ds_dev.ans_vocab)

# %%
import pandas as pd

y_true, y_pred = trainer.get_predictions(model, ds_dev)

questions = []
y_true_str = []
y_pred_str = []
for i, s in enumerate(ds_dev.samples):
    questions.append(s['prompt'])
    y_true_str.append(ds_train.ans_vocab.string(y_true[i]))
    y_pred_str.append(ds_train.ans_vocab.string(y_pred[i]))
    
    
res = pd.DataFrame({
    'question': questions,
    'y_true': y_true_str,
    'y_pred': y_pred_str
})

res[res['y_true'] != res['y_pred']]
# Out:
#                               question y_true y_pred
# 172  How many blue squares are there ?      1      2
# 219         Are there 4 rubber items ?  False   True

# %%
VQAInstanceDistribution2.to_debug_rep(ds_train.samples)[27]
# Out:
# {'TYPE': 'exists_count',
#  'PROMPT': 'Are there 2 brown plastic items ? --> False',
#  'SCENE ': array([['0', 'blue rubber circle'],
#         ['0', 'cyan plastic circle'],
#         ['0', 'gray rubber triangle'],
#         ['1', 'brown plastic circle'],
#         ['0', 'blue metal triangle'],
#         ['0', 'cyan plastic square']], dtype='<U21')}
