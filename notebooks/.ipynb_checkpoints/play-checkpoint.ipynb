# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
import torch.nn as nn

_include_('curriculum_vqa')
_include_('commons')

seed = 1
np.random.seed(seed)
torch.manual_seed(seed);

from cvqa import datasets, models, trainers, viz
from commons import debug

data_bin = f'{DEV_HOME}/data-bin'

# %%
8.64e+19
# Out:
# 8.64e+19

# %%
8.64*10**19
# Out:
# 8.64e+19

# %%
import matplotlib.pyplot as plt

M = 1e+6
B = 1e+9


N = np.linspace(0, 175*B, 1000)
D = 1000000*np.sqrt(N)


fig, ax = plt.subplots(figsize=(12,8))
ax.set_yscale('log')
# ax.set_xscale('log')
# ax.set_xlim(left=10, right=10**12)
# ax.set_ylim(bottom=10, top=10**13)

# plt.xticks(ticks=[10**])

plt.scatter([11000*M], [1000*B], label='T5-11B')
plt.scatter([355*M], [2000*B], label='RoBERTa-Large')
plt.scatter([174600*M], [300*B], label='GPT-3')

plt.plot(N, D);
plt.legend();

# %%
import pandas as pd

df = pd.read_csv(f'{data_bin}/misc/gpt3-res.csv', sep=' ')

df['F-Z'] = df['FS_175B'] - df['ZS_175B']
COLS = ['Name', 'Metric', 'Split', 'SOTA', 'K', 'ZS_175B', 'OS_175B', 'FS_175B', 'F-Z']
df = df[COLS]
df = df[df['Metric'] == 'acc']
df.sort_values('F-Z')
# Out:
#               Name Metric Split  SOTA      K  ZS_175B  OS_175B  FS_175B   F-Z
# 45         ANLI-R2    acc  test  50.7   50.0     35.4     33.9     34.0  -1.4
# 41          ReCoRD    acc   dev  92.5   32.0     90.2     90.2     89.0  -1.2
# 27          RACE-m    acc  test  93.1   10.0     58.4     57.4     58.1  -0.3
# 22  ARC(Challenge)    acc  test  78.5   50.0     51.4     53.2     51.5   0.1
# 19        Winograd    acc  test  93.8    7.0     88.3     89.7     88.6   0.3
# 0        HellaSwag    acc   dev  85.6   20.0     78.9     78.1     79.3   0.4
# 35            Copa    acc   dev  94.8   32.0     91.0     87.0     92.0   1.0
# 23       ARC(Easy)    acc  test  92.0   50.0     68.8     71.2     70.1   1.3
# 26          RACE-h    acc  test  90.0   10.0     45.5     45.9     46.8   1.3
# 21            PIQA    acc   dev  77.1   50.0     81.0     80.5     82.3   1.3
# 44         ANLI-R1    acc  test  73.8   50.0     34.6     32.0     36.8   2.2
# 3       StoryCloze    acc  test  91.8   70.0     83.2     84.7     87.7   4.5
# 39         MultiRC    acc   dev  62.3   32.0     27.6     27.6     32.5   4.9
# 46         ANLI-R3    acc  test  48.3   50.0     34.5     35.1     40.2   5.7
# 5         TriviaQA    acc   dev  68.0   64.0     64.3     68.0     71.2   6.9
# 20      Winogrande    acc   dev  84.6   50.0     70.2     73.2     77.7   7.5
# 24      OpenBookQA    acc  test  87.2  100.0     57.6     58.8     65.4   7.8
# 36             RTE    acc   dev  92.5   32.0     63.5     70.4     72.9   9.4
# 38             WSC    acc   dev  93.8   32.0     65.4     69.2     75.0   9.6
# 1          LAMBADA    acc  test  68.0   15.0     76.2     72.5     86.4  10.2
# 4              NQs    acc  test  44.5   64.0     14.6     23.0     29.9  15.3
# 32           BoolQ    acc   dev  91.0   32.0     60.5     76.7     77.5  17.0
# 6            WebQs    acc  test  45.5   64.0     14.4     25.3     41.5  27.1
# 33              CB    acc   dev  96.9   32.0     46.4     64.3     82.1  35.7
# 37             WiC    acc   dev  76.1   32.0      0.0     48.6     55.3  55.3

# %%
s = df['F-Z'].sort_values()
s.reset_index().plot()
# Out:
# <AxesSubplot:>
